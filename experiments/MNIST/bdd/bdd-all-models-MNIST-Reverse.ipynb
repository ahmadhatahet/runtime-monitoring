# %%
import os
os.chdir('../..')

# %%
from utilities.utils import *
from utilities.pathManager import fetchPaths
from utilities.MonitorUnifiedBDD import build_bdd_multi_etas
from utilities.train_models import train_models
from utilities.bdd_test_thresholds import run_parallel

# %%
import pandas as pd
import numpy as np
import sys
import gc
import copy
from pathlib import Path
from itertools import product

# %%
Path().cwd()
# Out:
# PosixPath('/home/ah19/runtime-monitoring')

# %%
# env variables
REPO_PATH = '/home/ah19/runtime-monitoring'
DATASET = 'MNIST'

# get essential paths
base = Path().cwd()
paths = fetchPaths(base, DATASET)
path = paths[DATASET.lower()]
path_dataset = paths["dataset"]


# from GTSRB.trainingModels.GTSRB_CNN import GTSRB_CNN
# model = GTSRB_CNN

# tf_train = T.Compose([
#     T.ToTensor(),
#     T.Resize((32, 32)),
#     T.Normalize((0.3359, 0.3110, 0.3224), (0.3359, 0.3110, 0.3224))
# ])


# tf_test = T.Compose([
#     T.ToTensor(),
#     T.Resize((32, 32)),
#     T.Normalize((0.3359, 0.3110, 0.3224), (0.3359, 0.3110, 0.3224))
# ])

# train_data = get_dataset(DATASET, path_dataset, train=True, transform=tf_train)
# test_data = get_dataset(DATASET, path_dataset, train=False, transform=tf_test)


model_setup = {'dropout': 0.2, 'first_layer_norm': False}

model_config = {
    'optim':'Adam',
    'batch_size': 256,
    'lr': 0.001,
    'epochs': 15,
    "patience": 3,
    "L2": 0.0,
    "L1": 0.0
}

# model varient name
models_name = f"{model_config['optim']}-{model_config['batch_size']}"
lhl_neurons = [30, 60, 100][::-1]

# %%
# # train model for each number of neurons
# for n in lhl_neurons:
#     # set last_hidden_neurons for model
#     model_setup["last_hidden_neurons"] = n
#     train_models(model, DATASET, f"{models_name}-{n}", train_data, test_data, model_setup, model_config)
#     gc.collect()

# %%
# run testing bdd thresholds for all models
# w/o neuron selections with eta = 0
# flavor ['raw', 'pca']

flavors = ['raw', 'pca'][::-1]
subset_neurons = [True, False][::-1]
max_time = 0
eta = 0
thlds = [0.9, 0, 0.5, 0.7, 0.3][::-1]

for thld, load_neurons, flavor, lhl_n in product(thlds, subset_neurons, flavors, lhl_neurons):
    print(f'Start Time: {dt.now()}')
    print(DATASET, models_name, lhl_n, flavor, load_neurons, thld, eta)
    run_parallel(DATASET, models_name, lhl_n, flavor, load_neurons, thld, eta)
    gc.collect()
# Out:
# Start Time: 2023-04-25 13:42:58.138452
# MNIST Adam-256 100 pca False 0.3 0
# [ FOUNDED: pca_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:42:58.224071
# MNIST Adam-256 60 pca False 0.3 0
# [ FOUNDED: pca_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:42:58.305441
# MNIST Adam-256 30 pca False 0.3 0
# [ FOUNDED: pca_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:42:58.387799
# MNIST Adam-256 100 raw False 0.3 0
# [ FOUNDED: raw_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:42:58.471180
# MNIST Adam-256 60 raw False 0.3 0
# [ FOUNDED: raw_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:42:58.553763
# MNIST Adam-256 30 raw False 0.3 0
# [ FOUNDED: raw_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:42:58.639800
# MNIST Adam-256 100 pca True 0.3 0
# [ FOUNDED: pca_components_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:42:58.724894
# MNIST Adam-256 60 pca True 0.3 0
# [ FOUNDED: pca_components_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:42:58.808311
# MNIST Adam-256 30 pca True 0.3 0
# [ FOUNDED: pca_components_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:42:58.888263
# MNIST Adam-256 100 raw True 0.3 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:42:58.969047
# MNIST Adam-256 60 raw True 0.3 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:42:59.045092
# MNIST Adam-256 30 raw True 0.3 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:42:59.145535
# MNIST Adam-256 100 pca False 0.7 0
# [ FOUNDED: pca_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:42:59.237059
# MNIST Adam-256 60 pca False 0.7 0
# [ FOUNDED: pca_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:42:59.326005
# MNIST Adam-256 30 pca False 0.7 0
# [ FOUNDED: pca_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:42:59.408197
# MNIST Adam-256 100 raw False 0.7 0
# [ FOUNDED: raw_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:42:59.484871
# MNIST Adam-256 60 raw False 0.7 0
# [ FOUNDED: raw_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:42:59.561064
# MNIST Adam-256 30 raw False 0.7 0
# [ FOUNDED: raw_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:42:59.642795
# MNIST Adam-256 100 pca True 0.7 0
# [ FOUNDED: pca_components_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:42:59.719830
# MNIST Adam-256 60 pca True 0.7 0
# [ FOUNDED: pca_components_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:42:59.796810
# MNIST Adam-256 30 pca True 0.7 0
# [ FOUNDED: pca_components_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:42:59.874670
# MNIST Adam-256 100 raw True 0.7 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:42:59.967190
# MNIST Adam-256 60 raw True 0.7 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:00.048844
# MNIST Adam-256 30 raw True 0.7 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:00.178472
# MNIST Adam-256 100 pca False 0.5 0
# [ FOUNDED: pca_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:00.258732
# MNIST Adam-256 60 pca False 0.5 0
# [ FOUNDED: pca_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:00.338258
# MNIST Adam-256 30 pca False 0.5 0
# [ FOUNDED: pca_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:00.417658
# MNIST Adam-256 100 raw False 0.5 0
# [ FOUNDED: raw_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:00.498174
# MNIST Adam-256 60 raw False 0.5 0
# [ FOUNDED: raw_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:00.581026
# MNIST Adam-256 30 raw False 0.5 0
# [ FOUNDED: raw_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:00.678840
# MNIST Adam-256 100 pca True 0.5 0
# [ FOUNDED: pca_components_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:00.760111
# MNIST Adam-256 60 pca True 0.5 0
# [ FOUNDED: pca_components_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:00.841346
# MNIST Adam-256 30 pca True 0.5 0
# [ FOUNDED: pca_components_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:00.923501
# MNIST Adam-256 100 raw True 0.5 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:01.003826
# MNIST Adam-256 60 raw True 0.5 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:01.087493
# MNIST Adam-256 30 raw True 0.5 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:01.183352
# MNIST Adam-256 100 pca False 0 0
# [ FOUNDED: pca_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:01.263930
# MNIST Adam-256 60 pca False 0 0
# [ FOUNDED: pca_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:01.343787
# MNIST Adam-256 30 pca False 0 0
# [ FOUNDED: pca_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:01.424048
# MNIST Adam-256 100 raw False 0 0
# [ FOUNDED: raw_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:01.505344
# MNIST Adam-256 60 raw False 0 0
# [ FOUNDED: raw_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:01.590501
# MNIST Adam-256 30 raw False 0 0
# [ FOUNDED: raw_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:01.682091
# MNIST Adam-256 100 pca True 0 0
# [ FOUNDED: pca_components_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:01.767356
# MNIST Adam-256 60 pca True 0 0
# [ FOUNDED: pca_components_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:01.848589
# MNIST Adam-256 30 pca True 0 0
# [ FOUNDED: pca_components_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:01.930461
# MNIST Adam-256 100 raw True 0 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:02.023469
# MNIST Adam-256 60 raw True 0 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:02.108357
# MNIST Adam-256 30 raw True 0 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:02.198100
# MNIST Adam-256 100 pca False 0.9 0
# [ FOUNDED: pca_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:02.282284
# MNIST Adam-256 60 pca False 0.9 0
# [ FOUNDED: pca_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:02.367783
# MNIST Adam-256 30 pca False 0.9 0
# [ FOUNDED: pca_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:02.449606
# MNIST Adam-256 100 raw False 0.9 0
# [ FOUNDED: raw_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:02.531208
# MNIST Adam-256 60 raw False 0.9 0
# [ FOUNDED: raw_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:02.612764
# MNIST Adam-256 30 raw False 0.9 0
# [ FOUNDED: raw_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:02.700063
# MNIST Adam-256 100 pca True 0.9 0
# [ FOUNDED: pca_components_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:02.787466
# MNIST Adam-256 60 pca True 0.9 0
# [ FOUNDED: pca_components_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:02.867878
# MNIST Adam-256 30 pca True 0.9 0
# [ FOUNDED: pca_components_MNIST_Adam-256-30 ]
# Start Time: 2023-04-25 13:43:02.949710
# MNIST Adam-256 100 raw True 0.9 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-100 ]
# Start Time: 2023-04-25 13:43:03.028767
# MNIST Adam-256 60 raw True 0.9 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-60 ]
# Start Time: 2023-04-25 13:43:03.106143
# MNIST Adam-256 30 raw True 0.9 0
# [ FOUNDED: raw_neurons_MNIST_Adam-256-30 ]
