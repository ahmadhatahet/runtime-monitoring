# %%
import os

import optuna
from optuna.trial import TrialState
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data
from torchvision import datasets
from torchvision import transforms

# %%
DEVICE = torch.device("cuda:1")
CLASSES = 10
DIR = os.getcwd()
EPOCHS = 10
DATASET = 'FashionMNIST'

# %%
train_data = getattr(datasets, DATASET)(DIR, train=True, download=True, transform=transforms.ToTensor())
test_data = getattr(datasets, DATASET)(DIR, train=False, download=True, transform=transforms.ToTensor())

len(train_data), len(test_data)
# Out:
# (60000, 10000)

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np

class SizeEstimator(object):

    def __init__(self, model, input_size=(1,1,32,32), bits=32):
        '''
        Estimates the size of PyTorch models in memory
        for a given input size
        '''
        self.model = model
        self.input_size = input_size
        self.bits = bits
        return

    def get_parameter_sizes(self):
        '''Get sizes of all parameters in `model`'''
        mods = list(self.model.modules())
        sizes = []
        
        for i in range(1,len(mods)):
            m = mods[i]
            p = list(m.parameters())
            for j in range(len(p)):
                sizes.append(np.array(p[j].size()))

        self.param_sizes = sizes
        return

    def get_output_sizes(self):
        '''Run sample input through each layer to get output sizes'''
        input_ = Variable(torch.FloatTensor(*self.input_size), volatile=True)
        mods = list(self.model.modules())
        out_sizes = []
        for i in range(1, len(mods)):
            m = mods[i]
            out = m(input_)
            out_sizes.append(np.array(out.size()))
            input_ = out

        self.out_sizes = out_sizes
        return

    def calc_param_bits(self):
        '''Calculate total number of bits to store `model` parameters'''
        total_bits = 0
        for i in range(len(self.param_sizes)):
            s = self.param_sizes[i]
            bits = np.prod(np.array(s))*self.bits
            total_bits += bits
        self.param_bits = total_bits
        return

    def calc_forward_backward_bits(self):
        '''Calculate bits to store forward and backward pass'''
        total_bits = 0
        for i in range(len(self.out_sizes)):
            s = self.out_sizes[i]
            bits = np.prod(np.array(s))*self.bits
            total_bits += bits
        # multiply by 2 for both forward AND backward
        self.forward_backward_bits = (total_bits*2)
        return

    def calc_input_bits(self):
        '''Calculate bits to store input'''
        self.input_bits = np.prod(np.array(self.input_size))*self.bits
        return

    def estimate_size(self):
        '''Estimate model size in memory in megabytes and bits'''
        self.get_parameter_sizes()
        self.get_output_sizes()
        self.calc_param_bits()
        self.calc_forward_backward_bits()
        self.calc_input_bits()
        total = self.param_bits + self.forward_backward_bits + self.input_bits

        total_megabytes = (total/8)/(1024**2)
        return total_megabytes, total

# %%
def dimensions_shape(x, k=3):
    return int(x - (k-1) - 1) + 1

# %%
def get_model_size(model):
    param_size = 0
    for param in model.parameters():
        param_size += param.nelement() * param.element_size()
    buffer_size = 0
    for buffer in model.buffers():
        buffer_size += buffer.nelement() * buffer.element_size()

    size_all_mb = (param_size + buffer_size) / 1024**2
    return size_all_mb

# %%
def define_model(trial):
    
    # We optimize the number of layers, hidden units and dropout ratio in each layer.
    in_channels = 1
    dim_shape = 28
    
    in_features = in_channels * dim_shape * dim_shape
    
    p = trial.suggest_float("dropout_l", 0.1, 0.5)
    
    conv_filter_1 = trial.suggest_int("conv_filter_1", 16, 96)
    conv_filter_2 = trial.suggest_int("conv_filter_2", 3, 16)
    
    n_layers_conv1 = trial.suggest_int("n_layers_conv1", 1, 3)
    n_layers_conv2 = trial.suggest_int("n_layers_conv2", 0, 3)
    n_layers_fc = trial.suggest_int("n_layers_fc", 1, 3)
    
    layers = [
        nn.BatchNorm2d(in_channels)
    ]
    
    

    for i in range(n_layers_conv1):
        
        layers.append(nn.Conv2d(in_channels, conv_filter_1, 3, bias=False))
        layers.append(nn.BatchNorm2d(conv_filter_1))
        layers.append(nn.ReLU())
        layers.append(nn.Dropout2d(p))
        
        dim_shape = dimensions_shape(dim_shape)

        in_channels = conv_filter_1
        
    

    for i in range(n_layers_conv2):
        
        layers.append(nn.Conv2d(in_channels, conv_filter_2, 3, bias=False))
        layers.append(nn.BatchNorm2d(conv_filter_2))
        layers.append(nn.ReLU())
        layers.append(nn.Dropout2d(p))
        
        dim_shape = dimensions_shape(dim_shape)

        in_channels = conv_filter_2
        
    layers.append(nn.Flatten())
    in_features = in_channels * dim_shape * dim_shape

    for i in range(n_layers_fc):
        out_features = trial.suggest_int("n_units_l{}".format(i), 50, 400)
        
        layers.append(nn.Linear(in_features, out_features, bias=False))
        layers.append(nn.BatchNorm1d(out_features))
        layers.append(nn.ReLU())
        layers.append(nn.Dropout(p))

        in_features = out_features

        
    layers.append(nn.Linear(in_features, 40, bias=False))
    layers.append(nn.BatchNorm1d(40))
    layers.append(nn.ReLU())
    layers.append(nn.Linear(40, CLASSES))

    return nn.Sequential(*layers)

# %%
def get_data(trial):
    
    BATCHSIZE = trial.suggest_int('batchsize', 32, 128)
    
    N_TRAIN_EXAMPLES = 20_000 // BATCHSIZE
    N_VALID_EXAMPLES = 2_500 // BATCHSIZE
    
    # Load FashionMNIST dataset.
    train_loader = torch.utils.data.DataLoader(train_data,batch_size=BATCHSIZE,shuffle=True)
    valid_loader = torch.utils.data.DataLoader(test_data,batch_size=BATCHSIZE,shuffle=True)

    return train_loader, valid_loader, BATCHSIZE, N_TRAIN_EXAMPLES, N_VALID_EXAMPLES

# %%
def objective(trial):
    # Generate the model.
    model = define_model(trial).to(DEVICE)
    
    # Generate the optimizers.
    loss_function = nn.CrossEntropyLoss()
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "SGD"])
    lr = trial.suggest_float("lr", 1e-5, 1e-1, log=True)
    optimizer = getattr(optim, optimizer_name)(model.parameters(), lr=lr)

    # Get the FashionMNIST dataset.
    train_loader, valid_loader, BATCHSIZE, N_TRAIN_EXAMPLES, N_VALID_EXAMPLES = get_data(trial)

    estimated_size = get_model_size(model)
    
    # Training of the model.
    for epoch in range(EPOCHS):
        model.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            # Limiting training data for faster epochs.
            if batch_idx >= N_TRAIN_EXAMPLES:
                break

            data, target = data.to(DEVICE), target.to(DEVICE)

            optimizer.zero_grad()
            output = model(data)
            loss = loss_function(output, target)
            loss.backward()
            optimizer.step()

        # Validation of the model.
        model.eval()
        correct = 0
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(valid_loader):
                # Limiting validation data.
                if batch_idx >= N_VALID_EXAMPLES:
                    break
                data, target = data.to(DEVICE), target.to(DEVICE)
                output = model(data)
                # Get the index of the max log-probability.
                pred = output.argmax(dim=1)
                correct += (pred == target).sum().item()

        accuracy = correct / (N_VALID_EXAMPLES * BATCHSIZE)

#         trial.report(epoch, accuracy, estimated_size)

        # Handle pruning based on the intermediate value.
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    return accuracy

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=200, timeout=60 * 60 * 2)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])


# print(f"Number of trials on the Pareto front: {len(study.best_trials)}")

# trial_with_highest_accuracy = max(study.best_trials, key=lambda t: t.values[1])
# print(f"Trial with highest accuracy: ")
# print(f"\tnumber: {trial_with_highest_accuracy.number}")
# print(f"\tparams: {trial_with_highest_accuracy.params}")
# print(f"\tvalues: {trial_with_highest_accuracy.values}")

print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2023-04-09 23:15:39,610] A new study created in memory with name: no-name-ef081e92-141a-4ee0-91af-825637bf430e
# [I 2023-04-09 23:17:23,648] Trial 0 finished with value: 0.8781074578989575 and parameters: {'dropout_l': 0.1819027312202544, 'conv_filter_1': 30, 'conv_filter_2': 10, 'n_layers_conv1': 3, 'n_layers_conv2': 3, 'n_layers_fc': 2, 'n_units_l0': 96, 'n_units_l1': 56, 'optimizer': 'SGD', 'lr': 0.07888620486750411, 'batchsize': 43}. Best is trial 0 with value: 0.8781074578989575.
# [I 2023-04-09 23:18:20,849] Trial 1 finished with value: 0.9024096385542169 and parameters: {'dropout_l': 0.16874804249654002, 'conv_filter_1': 75, 'conv_filter_2': 15, 'n_layers_conv1': 1, 'n_layers_conv2': 2, 'n_layers_fc': 2, 'n_units_l0': 86, 'n_units_l1': 187, 'optimizer': 'Adam', 'lr': 0.009345865811785183, 'batchsize': 83}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:19:24,794] Trial 2 finished with value: 0.8933658933658933 and parameters: {'dropout_l': 0.19959337115514725, 'conv_filter_1': 54, 'conv_filter_2': 16, 'n_layers_conv1': 3, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 356, 'n_units_l1': 307, 'optimizer': 'Adam', 'lr': 0.031702844651219385, 'batchsize': 63}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:20:31,962] Trial 3 finished with value: 0.8671497584541062 and parameters: {'dropout_l': 0.44782594990054403, 'conv_filter_1': 55, 'conv_filter_2': 3, 'n_layers_conv1': 3, 'n_layers_conv2': 0, 'n_layers_fc': 1, 'n_units_l0': 279, 'optimizer': 'Adam', 'lr': 0.03032686213375363, 'batchsize': 54}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:21:19,840] Trial 4 finished with value: 0.8347826086956521 and parameters: {'dropout_l': 0.42853559744038716, 'conv_filter_1': 70, 'conv_filter_2': 9, 'n_layers_conv1': 3, 'n_layers_conv2': 1, 'n_layers_fc': 2, 'n_units_l0': 177, 'n_units_l1': 90, 'optimizer': 'SGD', 'lr': 0.02354428377201657, 'batchsize': 105}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:22:16,122] Trial 5 finished with value: 0.7942148760330578 and parameters: {'dropout_l': 0.32448515643421705, 'conv_filter_1': 54, 'conv_filter_2': 9, 'n_layers_conv1': 2, 'n_layers_conv2': 3, 'n_layers_fc': 3, 'n_units_l0': 322, 'n_units_l1': 88, 'n_units_l2': 310, 'optimizer': 'Adam', 'lr': 0.025217632194950625, 'batchsize': 121}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:23:16,427] Trial 6 finished with value: 0.7693877551020408 and parameters: {'dropout_l': 0.4251004731079263, 'conv_filter_1': 21, 'conv_filter_2': 12, 'n_layers_conv1': 3, 'n_layers_conv2': 3, 'n_layers_fc': 2, 'n_units_l0': 335, 'n_units_l1': 115, 'optimizer': 'SGD', 'lr': 0.010469387584974243, 'batchsize': 70}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:24:34,178] Trial 7 finished with value: 0.8533653846153846 and parameters: {'dropout_l': 0.34180221116298015, 'conv_filter_1': 77, 'conv_filter_2': 5, 'n_layers_conv1': 1, 'n_layers_conv2': 3, 'n_layers_fc': 2, 'n_units_l0': 260, 'n_units_l1': 148, 'optimizer': 'Adam', 'lr': 0.0013924660188625875, 'batchsize': 52}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:25:50,020] Trial 8 finished with value: 0.7291666666666666 and parameters: {'dropout_l': 0.47771068135584327, 'conv_filter_1': 72, 'conv_filter_2': 13, 'n_layers_conv1': 2, 'n_layers_conv2': 3, 'n_layers_fc': 2, 'n_units_l0': 186, 'n_units_l1': 168, 'optimizer': 'Adam', 'lr': 0.0643469608423079, 'batchsize': 52}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:26:42,744] Trial 9 finished with value: 0.8990147783251231 and parameters: {'dropout_l': 0.22603786824744077, 'conv_filter_1': 69, 'conv_filter_2': 3, 'n_layers_conv1': 3, 'n_layers_conv2': 0, 'n_layers_fc': 3, 'n_units_l0': 367, 'n_units_l1': 296, 'n_units_l2': 309, 'optimizer': 'Adam', 'lr': 0.029997174104520147, 'batchsize': 116}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:27:33,105] Trial 10 finished with value: 0.3871753246753247 and parameters: {'dropout_l': 0.12470261392269777, 'conv_filter_1': 94, 'conv_filter_2': 16, 'n_layers_conv1': 1, 'n_layers_conv2': 2, 'n_layers_fc': 1, 'n_units_l0': 53, 'optimizer': 'SGD', 'lr': 1.0208046649466145e-05, 'batchsize': 88}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:28:30,679] Trial 11 finished with value: 0.8920545746388443 and parameters: {'dropout_l': 0.21681004150098543, 'conv_filter_1': 88, 'conv_filter_2': 6, 'n_layers_conv1': 1, 'n_layers_conv2': 1, 'n_layers_fc': 3, 'n_units_l0': 129, 'n_units_l1': 277, 'n_units_l2': 139, 'optimizer': 'Adam', 'lr': 0.0026205390850831734, 'batchsize': 89}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:29:25,890] Trial 12 finished with value: 0.8665289256198347 and parameters: {'dropout_l': 0.2609830938911185, 'conv_filter_1': 41, 'conv_filter_2': 13, 'n_layers_conv1': 2, 'n_layers_conv2': 2, 'n_layers_fc': 3, 'n_units_l0': 388, 'n_units_l1': 397, 'n_units_l2': 388, 'optimizer': 'Adam', 'lr': 0.0001243091487898132, 'batchsize': 121}. Best is trial 1 with value: 0.9024096385542169.
# [I 2023-04-09 23:30:20,214] Trial 13 finished with value: 0.91 and parameters: {'dropout_l': 0.10467983337825221, 'conv_filter_1': 81, 'conv_filter_2': 6, 'n_layers_conv1': 1, 'n_layers_conv2': 1, 'n_layers_fc': 3, 'n_units_l0': 222, 'n_units_l1': 213, 'n_units_l2': 231, 'optimizer': 'Adam', 'lr': 0.006080903433820362, 'batchsize': 100}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:31:10,237] Trial 14 finished with value: 0.8973737373737374 and parameters: {'dropout_l': 0.11149472608866053, 'conv_filter_1': 85, 'conv_filter_2': 7, 'n_layers_conv1': 1, 'n_layers_conv2': 1, 'n_layers_fc': 1, 'n_units_l0': 210, 'optimizer': 'Adam', 'lr': 0.004674211416820598, 'batchsize': 99}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:32:09,630] Trial 15 finished with value: 0.9054383116883117 and parameters: {'dropout_l': 0.15497677616321887, 'conv_filter_1': 80, 'conv_filter_2': 7, 'n_layers_conv1': 1, 'n_layers_conv2': 2, 'n_layers_fc': 3, 'n_units_l0': 149, 'n_units_l1': 207, 'n_units_l2': 50, 'optimizer': 'Adam', 'lr': 0.00034246249130128533, 'batchsize': 77}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:33:12,130] Trial 16 finished with value: 0.9022222222222223 and parameters: {'dropout_l': 0.13768767169864943, 'conv_filter_1': 85, 'conv_filter_2': 7, 'n_layers_conv1': 1, 'n_layers_conv2': 1, 'n_layers_fc': 3, 'n_units_l0': 150, 'n_units_l1': 240, 'n_units_l2': 80, 'optimizer': 'Adam', 'lr': 0.00031307654400063796, 'batchsize': 75}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:34:19,028] Trial 17 finished with value: 0.8601485148514851 and parameters: {'dropout_l': 0.2713499028551972, 'conv_filter_1': 63, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 2, 'n_layers_fc': 3, 'n_units_l0': 239, 'n_units_l1': 222, 'n_units_l2': 202, 'optimizer': 'Adam', 'lr': 0.00034629401014327985, 'batchsize': 101}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:35:05,587] Trial 18 finished with value: 0.5995085995085995 and parameters: {'dropout_l': 0.10458221146010804, 'conv_filter_1': 95, 'conv_filter_2': 8, 'n_layers_conv1': 2, 'n_layers_conv2': 1, 'n_layers_fc': 3, 'n_units_l0': 287, 'n_units_l1': 225, 'n_units_l2': 200, 'optimizer': 'SGD', 'lr': 9.145686178713461e-05, 'batchsize': 111}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:36:05,429] Trial 19 finished with value: 0.8780687397708674 and parameters: {'dropout_l': 0.363760738245435, 'conv_filter_1': 81, 'conv_filter_2': 11, 'n_layers_conv1': 1, 'n_layers_conv2': 2, 'n_layers_fc': 3, 'n_units_l0': 144, 'n_units_l1': 363, 'n_units_l2': 52, 'optimizer': 'Adam', 'lr': 0.0006702583200822639, 'batchsize': 94}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:37:07,072] Trial 20 finished with value: 0.8480753480753481 and parameters: {'dropout_l': 0.14569816762672844, 'conv_filter_1': 62, 'conv_filter_2': 5, 'n_layers_conv1': 1, 'n_layers_conv2': 1, 'n_layers_fc': 3, 'n_units_l0': 214, 'n_units_l1': 193, 'n_units_l2': 268, 'optimizer': 'Adam', 'lr': 2.348281356821878e-05, 'batchsize': 66}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:38:03,165] Trial 21 finished with value: 0.8975903614457831 and parameters: {'dropout_l': 0.16167457206953484, 'conv_filter_1': 77, 'conv_filter_2': 15, 'n_layers_conv1': 1, 'n_layers_conv2': 2, 'n_layers_fc': 2, 'n_units_l0': 94, 'n_units_l1': 184, 'optimizer': 'Adam', 'lr': 0.006217838372381532, 'batchsize': 83}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:38:59,883] Trial 22 finished with value: 0.8873009391588403 and parameters: {'dropout_l': 0.17169395715276933, 'conv_filter_1': 64, 'conv_filter_2': 7, 'n_layers_conv1': 1, 'n_layers_conv2': 2, 'n_layers_fc': 2, 'n_units_l0': 59, 'n_units_l1': 262, 'optimizer': 'Adam', 'lr': 0.0024723833981829028, 'batchsize': 79}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:39:57,955] Trial 23 finished with value: 0.903814935064935 and parameters: {'dropout_l': 0.23496577671350977, 'conv_filter_1': 45, 'conv_filter_2': 14, 'n_layers_conv1': 1, 'n_layers_conv2': 2, 'n_layers_fc': 2, 'n_units_l0': 107, 'n_units_l1': 144, 'optimizer': 'Adam', 'lr': 0.0007717532753985058, 'batchsize': 88}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:41:40,754] Trial 24 finished with value: 0.8950320512820513 and parameters: {'dropout_l': 0.2546790895873416, 'conv_filter_1': 45, 'conv_filter_2': 10, 'n_layers_conv1': 2, 'n_layers_conv2': 2, 'n_layers_fc': 3, 'n_units_l0': 173, 'n_units_l1': 138, 'n_units_l2': 129, 'optimizer': 'Adam', 'lr': 0.0008557305546107391, 'batchsize': 32}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:42:31,799] Trial 25 finished with value: 0.8852657004830918 and parameters: {'dropout_l': 0.29126877970180526, 'conv_filter_1': 38, 'conv_filter_2': 4, 'n_layers_conv1': 1, 'n_layers_conv2': 1, 'n_layers_fc': 1, 'n_units_l0': 117, 'optimizer': 'Adam', 'lr': 0.000230203123454383, 'batchsize': 108}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:43:22,470] Trial 26 finished with value: 0.1908831908831909 and parameters: {'dropout_l': 0.23196894028729706, 'conv_filter_1': 44, 'conv_filter_2': 8, 'n_layers_conv1': 1, 'n_layers_conv2': 2, 'n_layers_fc': 3, 'n_units_l0': 155, 'n_units_l1': 207, 'n_units_l2': 161, 'optimizer': 'SGD', 'lr': 6.655664550371052e-05, 'batchsize': 91}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:44:15,236] Trial 27 finished with value: 0.9090909090909091 and parameters: {'dropout_l': 0.19020588292251628, 'conv_filter_1': 50, 'conv_filter_2': 6, 'n_layers_conv1': 2, 'n_layers_conv2': 1, 'n_layers_fc': 2, 'n_units_l0': 198, 'n_units_l1': 250, 'optimizer': 'Adam', 'lr': 0.0014036038130736228, 'batchsize': 99}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:45:09,638] Trial 28 finished with value: 0.9081632653061225 and parameters: {'dropout_l': 0.1988393658773124, 'conv_filter_1': 32, 'conv_filter_2': 6, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 3, 'n_units_l0': 242, 'n_units_l1': 331, 'n_units_l2': 252, 'optimizer': 'Adam', 'lr': 0.002374424418064692, 'batchsize': 98}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:45:54,462] Trial 29 finished with value: 0.8643298969072165 and parameters: {'dropout_l': 0.19920795890791146, 'conv_filter_1': 33, 'conv_filter_2': 6, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 240, 'n_units_l1': 342, 'optimizer': 'SGD', 'lr': 0.0019469763987165064, 'batchsize': 97}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:46:47,639] Trial 30 finished with value: 0.9081715210355987 and parameters: {'dropout_l': 0.19236202077687228, 'conv_filter_1': 16, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 195, 'n_units_l1': 337, 'optimizer': 'Adam', 'lr': 0.003795185542924126, 'batchsize': 103}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:47:39,224] Trial 31 finished with value: 0.8981366459627329 and parameters: {'dropout_l': 0.18348901231522907, 'conv_filter_1': 18, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 200, 'n_units_l1': 326, 'optimizer': 'Adam', 'lr': 0.003946034898227852, 'batchsize': 105}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:48:26,116] Trial 32 finished with value: 0.9072681704260651 and parameters: {'dropout_l': 0.1966127176451732, 'conv_filter_1': 24, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 229, 'n_units_l1': 365, 'optimizer': 'Adam', 'lr': 0.012371162795811776, 'batchsize': 114}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:49:15,759] Trial 33 finished with value: 0.9017269736842105 and parameters: {'dropout_l': 0.1333012731000686, 'conv_filter_1': 26, 'conv_filter_2': 6, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 262, 'n_units_l1': 257, 'optimizer': 'Adam', 'lr': 0.006369970087109317, 'batchsize': 128}. Best is trial 13 with value: 0.91.
# [I 2023-04-09 23:50:06,086] Trial 34 finished with value: 0.9121732026143791 and parameters: {'dropout_l': 0.17046533455501367, 'conv_filter_1': 31, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 306, 'n_units_l1': 295, 'optimizer': 'Adam', 'lr': 0.0014401933374871253, 'batchsize': 102}. Best is trial 34 with value: 0.9121732026143791.
# [I 2023-04-09 23:50:56,660] Trial 35 finished with value: 0.9146440129449838 and parameters: {'dropout_l': 0.10687615117704982, 'conv_filter_1': 27, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 288, 'n_units_l1': 292, 'optimizer': 'Adam', 'lr': 0.001173770783555746, 'batchsize': 103}. Best is trial 35 with value: 0.9146440129449838.
# [I 2023-04-09 23:51:50,242] Trial 36 finished with value: 0.896163469557965 and parameters: {'dropout_l': 0.12057154477486365, 'conv_filter_1': 50, 'conv_filter_2': 3, 'n_layers_conv1': 3, 'n_layers_conv2': 1, 'n_layers_fc': 1, 'n_units_l0': 309, 'optimizer': 'Adam', 'lr': 0.0005696342406684738, 'batchsize': 109}. Best is trial 35 with value: 0.9146440129449838.
# [I 2023-04-09 23:52:36,822] Trial 37 finished with value: 0.9076109076109076 and parameters: {'dropout_l': 0.10406745384829656, 'conv_filter_1': 35, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 300, 'n_units_l1': 294, 'optimizer': 'Adam', 'lr': 0.001316131270306343, 'batchsize': 117}. Best is trial 35 with value: 0.9146440129449838.
# [I 2023-04-09 23:53:34,449] Trial 38 finished with value: 0.8707037643207856 and parameters: {'dropout_l': 0.1618357953901595, 'conv_filter_1': 29, 'conv_filter_2': 5, 'n_layers_conv1': 3, 'n_layers_conv2': 1, 'n_layers_fc': 2, 'n_units_l0': 335, 'n_units_l1': 247, 'optimizer': 'SGD', 'lr': 0.012979864878284201, 'batchsize': 94}. Best is trial 35 with value: 0.9146440129449838.
# [I 2023-04-09 23:54:22,539] Trial 39 finished with value: 0.910609857978279 and parameters: {'dropout_l': 0.1416878441026963, 'conv_filter_1': 50, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 288, 'n_units_l1': 283, 'optimizer': 'Adam', 'lr': 0.0014872871435931663, 'batchsize': 126}. Best is trial 35 with value: 0.9146440129449838.
# [I 2023-04-09 23:55:10,454] Trial 40 finished with value: 0.885547201336675 and parameters: {'dropout_l': 0.10071345021096524, 'conv_filter_1': 59, 'conv_filter_2': 3, 'n_layers_conv1': 3, 'n_layers_conv2': 0, 'n_layers_fc': 1, 'n_units_l0': 268, 'optimizer': 'Adam', 'lr': 0.09801921454858713, 'batchsize': 126}. Best is trial 35 with value: 0.9146440129449838.
# [I 2023-04-09 23:56:02,096] Trial 41 finished with value: 0.9198347107438016 and parameters: {'dropout_l': 0.12401450648342294, 'conv_filter_1': 50, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 290, 'n_units_l1': 279, 'optimizer': 'Adam', 'lr': 0.0014509233997528242, 'batchsize': 121}. Best is trial 41 with value: 0.9198347107438016.
# [I 2023-04-09 23:56:47,544] Trial 42 finished with value: 0.9098360655737705 and parameters: {'dropout_l': 0.13919765206984022, 'conv_filter_1': 37, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 284, 'n_units_l1': 278, 'optimizer': 'Adam', 'lr': 0.001189925725554667, 'batchsize': 122}. Best is trial 41 with value: 0.9198347107438016.
# [I 2023-04-09 23:57:38,553] Trial 43 finished with value: 0.9033333333333333 and parameters: {'dropout_l': 0.12497165178973958, 'conv_filter_1': 50, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 338, 'n_units_l1': 306, 'optimizer': 'Adam', 'lr': 0.0005942367418734197, 'batchsize': 120}. Best is trial 41 with value: 0.9198347107438016.
# [I 2023-04-09 23:58:27,448] Trial 44 finished with value: 0.8936688311688312 and parameters: {'dropout_l': 0.38174207812314986, 'conv_filter_1': 58, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 312, 'n_units_l1': 273, 'optimizer': 'Adam', 'lr': 0.0017909967275524287, 'batchsize': 112}. Best is trial 41 with value: 0.9198347107438016.
# [I 2023-04-09 23:59:15,554] Trial 45 finished with value: 0.9085365853658537 and parameters: {'dropout_l': 0.1415893497413615, 'conv_filter_1': 22, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 360, 'n_units_l1': 315, 'optimizer': 'Adam', 'lr': 0.007311011342437945, 'batchsize': 123}. Best is trial 41 with value: 0.9198347107438016.
# [I 2023-04-10 00:00:02,323] Trial 46 finished with value: 0.8962148962148963 and parameters: {'dropout_l': 0.16816146780622493, 'conv_filter_1': 28, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 295, 'n_units_l1': 283, 'optimizer': 'SGD', 'lr': 0.01645521976720076, 'batchsize': 117}. Best is trial 41 with value: 0.9198347107438016.
# [I 2023-04-10 00:00:53,528] Trial 47 finished with value: 0.9224774405250205 and parameters: {'dropout_l': 0.12158960179933391, 'conv_filter_1': 69, 'conv_filter_2': 4, 'n_layers_conv1': 3, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 321, 'n_units_l1': 228, 'optimizer': 'Adam', 'lr': 0.00433290272480498, 'batchsize': 106}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:01:46,571] Trial 48 finished with value: 0.9100704517198508 and parameters: {'dropout_l': 0.1256312105550306, 'conv_filter_1': 55, 'conv_filter_2': 4, 'n_layers_conv1': 3, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 385, 'n_units_l1': 301, 'optimizer': 'Adam', 'lr': 0.0032538152730431074, 'batchsize': 127}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:02:40,593] Trial 49 finished with value: 0.8904991948470209 and parameters: {'dropout_l': 0.1497153133874408, 'conv_filter_1': 71, 'conv_filter_2': 3, 'n_layers_conv1': 3, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 323, 'n_units_l1': 238, 'optimizer': 'Adam', 'lr': 0.055822049892869055, 'batchsize': 108}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:03:27,272] Trial 50 finished with value: 0.9160613397901534 and parameters: {'dropout_l': 0.20997511895747867, 'conv_filter_1': 67, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 350, 'n_units_l1': 357, 'optimizer': 'Adam', 'lr': 0.0004718691655471055, 'batchsize': 118}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:04:11,999] Trial 51 finished with value: 0.9067796610169492 and parameters: {'dropout_l': 0.2161314203875745, 'conv_filter_1': 66, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 349, 'n_units_l1': 357, 'optimizer': 'Adam', 'lr': 0.0004254757069825159, 'batchsize': 118}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:05:05,833] Trial 52 finished with value: 0.9197994987468672 and parameters: {'dropout_l': 0.1186287735672113, 'conv_filter_1': 68, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 273, 'n_units_l1': 398, 'optimizer': 'Adam', 'lr': 0.00016843916258707829, 'batchsize': 114}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:05:58,138] Trial 53 finished with value: 0.912711182622687 and parameters: {'dropout_l': 0.11718130579474655, 'conv_filter_1': 74, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 377, 'n_units_l1': 394, 'optimizer': 'Adam', 'lr': 0.0001538813848858171, 'batchsize': 113}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:06:46,387] Trial 54 finished with value: 0.9047619047619048 and parameters: {'dropout_l': 0.12545627559158928, 'conv_filter_1': 68, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 398, 'n_units_l1': 381, 'optimizer': 'Adam', 'lr': 4.583458553718732e-05, 'batchsize': 114}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:07:41,577] Trial 55 finished with value: 0.8999179655455292 and parameters: {'dropout_l': 0.11334660115937609, 'conv_filter_1': 75, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 371, 'n_units_l1': 389, 'optimizer': 'Adam', 'lr': 0.0001974248027516023, 'batchsize': 106}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:08:34,181] Trial 56 finished with value: 0.9119318181818182 and parameters: {'dropout_l': 0.15446213375090367, 'conv_filter_1': 74, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 274, 'n_units_l1': 374, 'optimizer': 'Adam', 'lr': 0.00015997380501015242, 'batchsize': 112}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:09:22,312] Trial 57 finished with value: 0.906910569105691 and parameters: {'dropout_l': 0.11818039488799487, 'conv_filter_1': 67, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 325, 'n_units_l1': 350, 'optimizer': 'Adam', 'lr': 0.00012762330743457662, 'batchsize': 123}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:10:11,248] Trial 58 finished with value: 0.758592132505176 and parameters: {'dropout_l': 0.3113528291529064, 'conv_filter_1': 71, 'conv_filter_2': 11, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 351, 'n_units_l1': 380, 'optimizer': 'SGD', 'lr': 0.00026197417900280303, 'batchsize': 115}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:11:23,193] Trial 59 finished with value: 0.8793103448275862 and parameters: {'dropout_l': 0.2147893719129189, 'conv_filter_1': 91, 'conv_filter_2': 5, 'n_layers_conv1': 3, 'n_layers_conv2': 1, 'n_layers_fc': 1, 'n_units_l0': 380, 'optimizer': 'Adam', 'lr': 4.525723494348737e-05, 'batchsize': 58}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:12:11,536] Trial 60 finished with value: 0.9171668667466987 and parameters: {'dropout_l': 0.17579353842193157, 'conv_filter_1': 61, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 253, 'n_units_l1': 370, 'optimizer': 'Adam', 'lr': 0.0004510867747516719, 'batchsize': 119}. Best is trial 47 with value: 0.9224774405250205.
# [I 2023-04-10 00:13:03,879] Trial 61 finished with value: 0.9231692677070829 and parameters: {'dropout_l': 0.17578166518664656, 'conv_filter_1': 61, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 254, 'n_units_l1': 399, 'optimizer': 'Adam', 'lr': 0.0004919153512392123, 'batchsize': 119}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:13:54,985] Trial 62 finished with value: 0.905562224889956 and parameters: {'dropout_l': 0.17363282804423902, 'conv_filter_1': 61, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 255, 'n_units_l1': 367, 'optimizer': 'Adam', 'lr': 0.00041747652035459607, 'batchsize': 119}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:14:44,368] Trial 63 finished with value: 0.9109756097560976 and parameters: {'dropout_l': 0.24872269207421852, 'conv_filter_1': 65, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 253, 'n_units_l1': 396, 'optimizer': 'Adam', 'lr': 0.0009380384298407025, 'batchsize': 123}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:15:36,629] Trial 64 finished with value: 0.9122308004876066 and parameters: {'dropout_l': 0.1782498670029277, 'conv_filter_1': 59, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 278, 'n_units_l1': 400, 'optimizer': 'Adam', 'lr': 0.0003771173827856945, 'batchsize': 107}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:16:24,582] Trial 65 finished with value: 0.8987603305785123 and parameters: {'dropout_l': 0.47941573441841295, 'conv_filter_1': 53, 'conv_filter_2': 6, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 229, 'n_units_l1': 318, 'optimizer': 'Adam', 'lr': 0.0006832615523337892, 'batchsize': 110}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:17:16,300] Trial 66 finished with value: 0.9175 and parameters: {'dropout_l': 0.15474916722849452, 'conv_filter_1': 63, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 246, 'n_units_l1': 354, 'optimizer': 'Adam', 'lr': 0.0005141571104814247, 'batchsize': 120}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:18:13,078] Trial 67 finished with value: 0.8851540616246498 and parameters: {'dropout_l': 0.15731784703867552, 'conv_filter_1': 62, 'conv_filter_2': 8, 'n_layers_conv1': 2, 'n_layers_conv2': 3, 'n_layers_fc': 2, 'n_units_l0': 254, 'n_units_l1': 59, 'optimizer': 'Adam', 'lr': 0.0005243807734323325, 'batchsize': 119}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:18:58,384] Trial 68 finished with value: 0.9136 and parameters: {'dropout_l': 0.21067434031640414, 'conv_filter_1': 79, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 217, 'n_units_l1': 376, 'optimizer': 'Adam', 'lr': 0.000276519294158528, 'batchsize': 125}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:19:45,851] Trial 69 finished with value: 0.6814049586776859 and parameters: {'dropout_l': 0.18339271955918596, 'conv_filter_1': 69, 'conv_filter_2': 9, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 266, 'n_units_l1': 349, 'optimizer': 'SGD', 'lr': 7.399785763750332e-05, 'batchsize': 121}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:20:42,458] Trial 70 finished with value: 0.9080459770114943 and parameters: {'dropout_l': 0.13259962233755468, 'conv_filter_1': 53, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 1, 'n_layers_fc': 2, 'n_units_l0': 246, 'n_units_l1': 171, 'optimizer': 'Adam', 'lr': 0.0009217246034232381, 'batchsize': 84}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:21:31,531] Trial 71 finished with value: 0.9180124223602485 and parameters: {'dropout_l': 0.1539119803889348, 'conv_filter_1': 66, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 294, 'n_units_l1': 351, 'optimizer': 'Adam', 'lr': 0.0004974695457996862, 'batchsize': 115}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:22:22,477] Trial 72 finished with value: 0.9118012422360249 and parameters: {'dropout_l': 0.15112878468770452, 'conv_filter_1': 57, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 314, 'n_units_l1': 355, 'optimizer': 'Adam', 'lr': 0.00048745895876553845, 'batchsize': 115}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:23:19,020] Trial 73 finished with value: 0.9154351395730707 and parameters: {'dropout_l': 0.15864022669198802, 'conv_filter_1': 64, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 275, 'n_units_l1': 340, 'optimizer': 'Adam', 'lr': 0.00022145464588049007, 'batchsize': 116}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:24:08,127] Trial 74 finished with value: 0.9156429156429157 and parameters: {'dropout_l': 0.2065781218795616, 'conv_filter_1': 61, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 295, 'n_units_l1': 367, 'optimizer': 'Adam', 'lr': 0.0003115860404945463, 'batchsize': 111}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:24:57,545] Trial 75 finished with value: 0.9095833333333333 and parameters: {'dropout_l': 0.13377467729452436, 'conv_filter_1': 67, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 229, 'n_units_l1': 389, 'optimizer': 'Adam', 'lr': 0.0007477622611242396, 'batchsize': 120}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:25:42,206] Trial 76 finished with value: 0.9009046052631579 and parameters: {'dropout_l': 0.18744425066593975, 'conv_filter_1': 72, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 332, 'n_units_l1': 326, 'optimizer': 'Adam', 'lr': 9.787022136213932e-05, 'batchsize': 128}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:26:52,844] Trial 77 finished with value: 0.9082828282828282 and parameters: {'dropout_l': 0.23929104796132245, 'conv_filter_1': 64, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 246, 'n_units_l1': 381, 'optimizer': 'Adam', 'lr': 0.00017522754582027005, 'batchsize': 45}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:27:51,842] Trial 78 finished with value: 0.9057211925866236 and parameters: {'dropout_l': 0.27414302856427597, 'conv_filter_1': 60, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 343, 'n_units_l1': 345, 'optimizer': 'Adam', 'lr': 0.001816664622573943, 'batchsize': 73}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:28:40,014] Trial 79 finished with value: 0.8996 and parameters: {'dropout_l': 0.16557455686867023, 'conv_filter_1': 56, 'conv_filter_2': 6, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 300, 'n_units_l1': 360, 'optimizer': 'Adam', 'lr': 0.0003600987417996716, 'batchsize': 125}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:29:29,984] Trial 80 finished with value: 0.877085877085877 and parameters: {'dropout_l': 0.1424708757259312, 'conv_filter_1': 69, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 1, 'n_layers_fc': 2, 'n_units_l0': 267, 'n_units_l1': 332, 'optimizer': 'Adam', 'lr': 0.0005233734161812059, 'batchsize': 117}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:30:22,037] Trial 81 finished with value: 0.9132231404958677 and parameters: {'dropout_l': 0.22587710608848238, 'conv_filter_1': 61, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 295, 'n_units_l1': 368, 'optimizer': 'Adam', 'lr': 0.0003593824279442325, 'batchsize': 110}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:31:09,698] Trial 82 finished with value: 0.9082719082719083 and parameters: {'dropout_l': 0.19887978604095297, 'conv_filter_1': 48, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 315, 'n_units_l1': 372, 'optimizer': 'Adam', 'lr': 0.0002652199576796105, 'batchsize': 111}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:32:02,569] Trial 83 finished with value: 0.9126602564102564 and parameters: {'dropout_l': 0.20821092330738986, 'conv_filter_1': 65, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 300, 'n_units_l1': 384, 'optimizer': 'Adam', 'lr': 0.0006979813100803066, 'batchsize': 104}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:32:54,913] Trial 84 finished with value: 0.9113821138211382 and parameters: {'dropout_l': 0.17994936865012143, 'conv_filter_1': 63, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 284, 'n_units_l1': 316, 'optimizer': 'Adam', 'lr': 0.0003121117721095786, 'batchsize': 123}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:33:42,203] Trial 85 finished with value: 0.9074818986323411 and parameters: {'dropout_l': 0.34569089454244306, 'conv_filter_1': 57, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 236, 'n_units_l1': 359, 'optimizer': 'Adam', 'lr': 0.0010513538797849564, 'batchsize': 113}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:34:31,402] Trial 86 finished with value: 0.815 and parameters: {'dropout_l': 0.13156351604441624, 'conv_filter_1': 54, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 327, 'n_units_l1': 400, 'optimizer': 'SGD', 'lr': 0.00045868415654457266, 'batchsize': 120}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:35:22,332] Trial 87 finished with value: 0.8701668701668702 and parameters: {'dropout_l': 0.45832016432545597, 'conv_filter_1': 76, 'conv_filter_2': 7, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 261, 'n_units_l1': 126, 'optimizer': 'Adam', 'lr': 0.00011196662046188865, 'batchsize': 117}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:36:16,465] Trial 88 finished with value: 0.8892914653784219 and parameters: {'dropout_l': 0.11193329533169628, 'conv_filter_1': 67, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 3, 'n_layers_fc': 2, 'n_units_l0': 289, 'n_units_l1': 372, 'optimizer': 'Adam', 'lr': 0.0002191900691641315, 'batchsize': 108}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:37:09,913] Trial 89 finished with value: 0.9118012422360249 and parameters: {'dropout_l': 0.14957485532575707, 'conv_filter_1': 70, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 271, 'n_units_l1': 217, 'optimizer': 'Adam', 'lr': 0.002424608480798906, 'batchsize': 115}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:37:58,627] Trial 90 finished with value: 0.9112903225806451 and parameters: {'dropout_l': 0.16793144029028279, 'conv_filter_1': 63, 'conv_filter_2': 13, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 304, 'n_units_l1': 192, 'optimizer': 'Adam', 'lr': 0.0008466589602934717, 'batchsize': 124}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:38:49,061] Trial 91 finished with value: 0.9121510673234812 and parameters: {'dropout_l': 0.146606605555073, 'conv_filter_1': 72, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 279, 'n_units_l1': 340, 'optimizer': 'Adam', 'lr': 0.0001317535797508242, 'batchsize': 116}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:39:40,802] Trial 92 finished with value: 0.9016528925619834 and parameters: {'dropout_l': 0.16124839176555184, 'conv_filter_1': 65, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 317, 'n_units_l1': 351, 'optimizer': 'Adam', 'lr': 0.00021684241931837388, 'batchsize': 121}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:40:28,448] Trial 93 finished with value: 0.885551948051948 and parameters: {'dropout_l': 0.40703361450254194, 'conv_filter_1': 60, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 274, 'n_units_l1': 339, 'optimizer': 'Adam', 'lr': 0.00030213073561589546, 'batchsize': 112}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:41:19,726] Trial 94 finished with value: 0.9225181598062954 and parameters: {'dropout_l': 0.10002370903955368, 'conv_filter_1': 62, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 292, 'n_units_l1': 386, 'optimizer': 'Adam', 'lr': 0.0005535324111160639, 'batchsize': 118}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:42:10,853] Trial 95 finished with value: 0.9188861985472155 and parameters: {'dropout_l': 0.10630070528959029, 'conv_filter_1': 58, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 360, 'n_units_l1': 390, 'optimizer': 'Adam', 'lr': 0.0006076750908805453, 'batchsize': 118}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:42:57,981] Trial 96 finished with value: 0.9079903147699758 and parameters: {'dropout_l': 0.12236728069305772, 'conv_filter_1': 52, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 366, 'n_units_l1': 388, 'optimizer': 'Adam', 'lr': 0.0006227758257726218, 'batchsize': 118}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:43:51,987] Trial 97 finished with value: 0.9102459016393443 and parameters: {'dropout_l': 0.10031618274446402, 'conv_filter_1': 58, 'conv_filter_2': 16, 'n_layers_conv1': 3, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 358, 'n_units_l1': 230, 'optimizer': 'Adam', 'lr': 0.0030909757368569016, 'batchsize': 122}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:44:41,171] Trial 98 finished with value: 0.9046052631578947 and parameters: {'dropout_l': 0.11322508142628948, 'conv_filter_1': 56, 'conv_filter_2': 12, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 254, 'n_units_l1': 266, 'optimizer': 'Adam', 'lr': 0.001203538650694223, 'batchsize': 128}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:45:27,758] Trial 99 finished with value: 0.8609022556390977 and parameters: {'dropout_l': 0.10841020036820832, 'conv_filter_1': 47, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 220, 'n_units_l1': 389, 'optimizer': 'SGD', 'lr': 0.001562192565921129, 'batchsize': 114}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:46:17,857] Trial 100 finished with value: 0.904 and parameters: {'dropout_l': 0.12958820922480338, 'conv_filter_1': 68, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 210, 'n_units_l1': 394, 'optimizer': 'Adam', 'lr': 0.0005903987129761678, 'batchsize': 125}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:47:04,708] Trial 101 finished with value: 0.9115646258503401 and parameters: {'dropout_l': 0.13902192043426237, 'conv_filter_1': 62, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 293, 'n_units_l1': 364, 'optimizer': 'Adam', 'lr': 0.0004554396419233021, 'batchsize': 119}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:47:57,293] Trial 102 finished with value: 0.9099173553719008 and parameters: {'dropout_l': 0.11936352851678472, 'conv_filter_1': 60, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 283, 'n_units_l1': 377, 'optimizer': 'Adam', 'lr': 0.00038635297431989794, 'batchsize': 110}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:48:46,932] Trial 103 finished with value: 0.9215607401448109 and parameters: {'dropout_l': 0.20378247890225343, 'conv_filter_1': 66, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 341, 'n_units_l1': 364, 'optimizer': 'Adam', 'lr': 0.0007562904166788545, 'batchsize': 113}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:49:36,096] Trial 104 finished with value: 0.9220672682526662 and parameters: {'dropout_l': 0.10027865949056476, 'conv_filter_1': 67, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 341, 'n_units_l1': 380, 'optimizer': 'Adam', 'lr': 0.004526605001991324, 'batchsize': 106}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:50:30,091] Trial 105 finished with value: 0.8976897689768977 and parameters: {'dropout_l': 0.10707501552426749, 'conv_filter_1': 43, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 342, 'n_units_l1': 383, 'optimizer': 'Adam', 'lr': 0.004821698958829946, 'batchsize': 101}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:51:24,133] Trial 106 finished with value: 0.9002403846153846 and parameters: {'dropout_l': 0.11914417656135325, 'conv_filter_1': 70, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 331, 'n_units_l1': 392, 'optimizer': 'Adam', 'lr': 0.009728106905526118, 'batchsize': 96}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:52:14,282] Trial 107 finished with value: 0.9064182194616978 and parameters: {'dropout_l': 0.12668624458560246, 'conv_filter_1': 66, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 308, 'n_units_l1': 374, 'optimizer': 'Adam', 'lr': 0.0008246673050952902, 'batchsize': 105}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:53:09,408] Trial 108 finished with value: 0.8992279561154003 and parameters: {'dropout_l': 0.10064116498352968, 'conv_filter_1': 63, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 1, 'n_layers_fc': 2, 'n_units_l0': 318, 'n_units_l1': 400, 'optimizer': 'Adam', 'lr': 0.005130137084471383, 'batchsize': 107}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:54:01,595] Trial 109 finished with value: 0.9207562349155269 and parameters: {'dropout_l': 0.17403512938071658, 'conv_filter_1': 73, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 343, 'n_units_l1': 379, 'optimizer': 'Adam', 'lr': 0.0010674342494960659, 'batchsize': 113}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:54:54,095] Trial 110 finished with value: 0.9062751407884151 and parameters: {'dropout_l': 0.11281519361105656, 'conv_filter_1': 75, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 343, 'n_units_l1': 386, 'optimizer': 'Adam', 'lr': 0.007854924730347674, 'batchsize': 113}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:55:47,142] Trial 111 finished with value: 0.9105590062111801 and parameters: {'dropout_l': 0.17452308872981034, 'conv_filter_1': 72, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 367, 'n_units_l1': 377, 'optimizer': 'Adam', 'lr': 0.0009848057198302972, 'batchsize': 115}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:56:35,147] Trial 112 finished with value: 0.9074380165289256 and parameters: {'dropout_l': 0.1373902666344828, 'conv_filter_1': 69, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 349, 'n_units_l1': 365, 'optimizer': 'Adam', 'lr': 0.002018176347471175, 'batchsize': 121}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:57:30,503] Trial 113 finished with value: 0.9195162635529608 and parameters: {'dropout_l': 0.1920224633502049, 'conv_filter_1': 83, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 322, 'n_units_l1': 393, 'optimizer': 'Adam', 'lr': 0.0011098197150964716, 'batchsize': 109}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:58:28,712] Trial 114 finished with value: 0.9220183486238532 and parameters: {'dropout_l': 0.1874784687123758, 'conv_filter_1': 84, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 337, 'n_units_l1': 392, 'optimizer': 'Adam', 'lr': 0.00295274914690967, 'batchsize': 109}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 00:59:16,410] Trial 115 finished with value: 0.9165971643035863 and parameters: {'dropout_l': 0.19199110302437083, 'conv_filter_1': 83, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 337, 'n_units_l1': 396, 'optimizer': 'Adam', 'lr': 0.0038067294175708585, 'batchsize': 109}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:00:13,062] Trial 116 finished with value: 0.9033171521035599 and parameters: {'dropout_l': 0.18616612247033312, 'conv_filter_1': 93, 'conv_filter_2': 6, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 322, 'n_units_l1': 205, 'optimizer': 'Adam', 'lr': 0.0021035329108790657, 'batchsize': 103}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:01:05,731] Trial 117 finished with value: 0.9159146841673503 and parameters: {'dropout_l': 0.10784270497149953, 'conv_filter_1': 82, 'conv_filter_2': 6, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 362, 'n_units_l1': 385, 'optimizer': 'Adam', 'lr': 0.001504665510039074, 'batchsize': 106}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:01:57,685] Trial 118 finished with value: 0.9062626262626262 and parameters: {'dropout_l': 0.2270268302617513, 'conv_filter_1': 88, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 353, 'n_units_l1': 392, 'optimizer': 'Adam', 'lr': 0.0010980035753262109, 'batchsize': 99}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:02:46,853] Trial 119 finished with value: 0.8786488740617181 and parameters: {'dropout_l': 0.14635495926423236, 'conv_filter_1': 79, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 331, 'n_units_l1': 382, 'optimizer': 'SGD', 'lr': 0.002690674215980016, 'batchsize': 109}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:03:38,023] Trial 120 finished with value: 0.8737824675324676 and parameters: {'dropout_l': 0.4981446076937744, 'conv_filter_1': 77, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 307, 'n_units_l1': 157, 'optimizer': 'Adam', 'lr': 0.0034247233366033873, 'batchsize': 112}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:04:27,657] Trial 121 finished with value: 0.9133825944170771 and parameters: {'dropout_l': 0.15284225321242434, 'conv_filter_1': 88, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 342, 'n_units_l1': 353, 'optimizer': 'Adam', 'lr': 0.0007945723939708891, 'batchsize': 116}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:05:20,898] Trial 122 finished with value: 0.87468671679198 and parameters: {'dropout_l': 0.16385887928048543, 'conv_filter_1': 90, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 325, 'n_units_l1': 400, 'optimizer': 'Adam', 'lr': 1.456903627945043e-05, 'batchsize': 114}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:06:13,531] Trial 123 finished with value: 0.917106867127184 and parameters: {'dropout_l': 0.12757987131499005, 'conv_filter_1': 86, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 371, 'n_units_l1': 360, 'optimizer': 'Adam', 'lr': 0.00426552532040333, 'batchsize': 107}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:07:02,755] Trial 124 finished with value: 0.9111384111384111 and parameters: {'dropout_l': 0.2005854016949662, 'conv_filter_1': 73, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 393, 'n_units_l1': 378, 'optimizer': 'Adam', 'lr': 0.0012678790551273525, 'batchsize': 111}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:07:53,313] Trial 125 finished with value: 0.9031476997578692 and parameters: {'dropout_l': 0.13606767028889155, 'conv_filter_1': 67, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 347, 'n_units_l1': 390, 'optimizer': 'Adam', 'lr': 0.005548501950252364, 'batchsize': 118}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:08:42,833] Trial 126 finished with value: 0.9166666666666666 and parameters: {'dropout_l': 0.10009618563689782, 'conv_filter_1': 84, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 357, 'n_units_l1': 370, 'optimizer': 'Adam', 'lr': 0.0017019206965474829, 'batchsize': 104}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:09:44,910] Trial 127 finished with value: 0.9122596153846154 and parameters: {'dropout_l': 0.11659508472037824, 'conv_filter_1': 65, 'conv_filter_2': 9, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 334, 'n_units_l1': 382, 'optimizer': 'Adam', 'lr': 0.002779920773287505, 'batchsize': 64}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:10:36,462] Trial 128 finished with value: 0.911504424778761 and parameters: {'dropout_l': 0.15633515477284304, 'conv_filter_1': 80, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 377, 'n_units_l1': 345, 'optimizer': 'Adam', 'lr': 0.0006676821230749441, 'batchsize': 113}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:11:22,871] Trial 129 finished with value: 0.9105090311986864 and parameters: {'dropout_l': 0.17836554455376893, 'conv_filter_1': 59, 'conv_filter_2': 6, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 320, 'n_units_l1': 374, 'optimizer': 'Adam', 'lr': 0.0005469833188597467, 'batchsize': 116}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:12:15,610] Trial 130 finished with value: 0.8971311475409836 and parameters: {'dropout_l': 0.17023273233179192, 'conv_filter_1': 71, 'conv_filter_2': 5, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 304, 'n_units_l1': 393, 'optimizer': 'Adam', 'lr': 0.0074792961324040225, 'batchsize': 122}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:13:06,172] Trial 131 finished with value: 0.9108333333333334 and parameters: {'dropout_l': 0.1881130509133104, 'conv_filter_1': 62, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 243, 'n_units_l1': 370, 'optimizer': 'Adam', 'lr': 0.0007140638767013879, 'batchsize': 120}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:13:53,980] Trial 132 finished with value: 0.903954802259887 and parameters: {'dropout_l': 0.19463483010456095, 'conv_filter_1': 58, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 259, 'n_units_l1': 363, 'optimizer': 'Adam', 'lr': 0.0009974950687653172, 'batchsize': 118}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:14:45,236] Trial 133 finished with value: 0.912765106042417 and parameters: {'dropout_l': 0.17731241679037155, 'conv_filter_1': 68, 'conv_filter_2': 4, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 234, 'n_units_l1': 326, 'optimizer': 'Adam', 'lr': 0.0005657025613729215, 'batchsize': 119}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:15:34,758] Trial 134 finished with value: 0.917741935483871 and parameters: {'dropout_l': 0.20265504134633375, 'conv_filter_1': 64, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 247, 'n_units_l1': 95, 'optimizer': 'Adam', 'lr': 0.0008931283088361283, 'batchsize': 124}. Best is trial 61 with value: 0.9231692677070829.
# [I 2023-04-10 01:16:23,644] Trial 135 finished with value: 0.9133064516129032 and parameters: {'dropout_l': 0.2189960452080857, 'conv_filter_1': 65, 'conv_filter_2': 3, 'n_layers_conv1': 2, 'n_layers_conv2': 0, 'n_layers_fc': 2, 'n_units_l0': 268, 'n_units_l1': 94, 'optimizer': 'Adam', 'lr': 0.0009515982786843605, 'batchsize': 124}. Best is trial 61 with value: 0.9231692677070829.
# Study statistics:
#   Number of finished trials:  136
#   Number of pruned trials:  0
#   Number of complete trials:  136
# Best trial:
#   Value:  0.9231692677070829
#   Params:
#     dropout_l: 0.17578166518664656
#     conv_filter_1: 61
#     conv_filter_2: 4
#     n_layers_conv1: 2
#     n_layers_conv2: 0
#     n_layers_fc: 2
#     n_units_l0: 254
#     n_units_l1: 399
#     optimizer: Adam
#     lr: 0.0004919153512392123
#     batchsize: 119

# %%
# df = study.trials_dataframe().sort_values(['values_0', 'values_1'], ascending=False)
df = study.trials_dataframe().sort_values('value', ascending=False)
df.to_csv(DIR + f'/optuna-{DATASET.lower()}.csv', index=False)

# %%
df.head(7)
# Out:
#      number     value             datetime_start          datetime_complete  \
# 61       61  0.923169 2023-04-10 00:12:11.539183 2023-04-10 00:13:03.877949
# 94       94  0.922518 2023-04-10 00:40:28.453459 2023-04-10 00:41:19.725864
# 47       47  0.922477 2023-04-10 00:00:02.325247 2023-04-10 00:00:53.527314
# 104     104  0.922067 2023-04-10 00:48:46.936118 2023-04-10 00:49:36.095549
# 114     114  0.922018 2023-04-10 00:57:30.505754 2023-04-10 00:58:28.711100
# 103     103  0.921561 2023-04-10 00:47:57.295340 2023-04-10 00:48:46.931672
# 109     109  0.920756 2023-04-10 00:53:09.410687 2023-04-10 00:54:01.594921
#
#                   duration  params_batchsize  params_conv_filter_1  \
# 61  0 days 00:00:52.338766               119                    61
# 94  0 days 00:00:51.272405               118                    62
# 47  0 days 00:00:51.202067               106                    69
# 104 0 days 00:00:49.159431               106                    67
# 114 0 days 00:00:58.205346               109                    84
# 103 0 days 00:00:49.636332               113                    66
# 109 0 days 00:00:52.184234               113                    73
#
#      params_conv_filter_2  params_dropout_l  params_lr  params_n_layers_conv1  \
# 61                      4          0.175782   0.000492                      2
# 94                      4          0.100024   0.000554                      2
# 47                      4          0.121590   0.004333                      3
# 104                     4          0.100279   0.004527                      2
# 114                     5          0.187478   0.002953                      2
# 103                     4          0.203782   0.000756                      2
# 109                     5          0.174035   0.001067                      2
#
#      params_n_layers_conv2  params_n_layers_fc  params_n_units_l0  \
# 61                       0                   2                254
# 94                       0                   2                292
# 47                       0                   2                321
# 104                      0                   2                341
# 114                      0                   2                337
# 103                      0                   2                341
# 109                      0                   2                343
#
#      params_n_units_l1  params_n_units_l2 params_optimizer     state
# 61               399.0                NaN             Adam  COMPLETE
# 94               386.0                NaN             Adam  COMPLETE
# 47               228.0                NaN             Adam  COMPLETE
# 104              380.0                NaN             Adam  COMPLETE
# 114              392.0                NaN             Adam  COMPLETE
# 103              364.0                NaN             Adam  COMPLETE
# 109              379.0                NaN             Adam  COMPLETE

# %%
# Trial 17 finished with values: [0.905562224889956, 3.3138427734375] and parameters: {'dropout_l': 0.1709405615825048, 'conv_filter_1': 45, 'conv_filter_2': 8, 'n_layers_conv1': 2, 'n_layers_conv2': 1, 'n_layers_fc': 1, 'n_units_l0': 216, 'optimizer': 'Adam', 'lr': 0.0010785994045218131, 'batchsize': 51}.
