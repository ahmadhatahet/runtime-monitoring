# %%
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
cwd = Path().cwd()
curated_data_path = cwd / 'curated_data'

# %%
curated_data = 'mnist-L2NormDropout.csv'

# %%
df = pd.read_csv(curated_data_path / curated_data, delimiter=',')

# %%
pca = PCA()

# %%
y = df['y']
df.drop('y', axis=1, inplace=True)

# %%
df_pca = pd.DataFrame( pca.fit_transform(df) )

# %%
df_pca.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.304257  3.558668 -0.767439 -1.683618 -1.352886 -0.785181 -0.664798
# 1  5.651354 -0.473770 -1.267945  1.581038 -0.418286  0.779293 -0.970690
# 2 -1.894153  0.431429  1.845316  2.140064 -1.607043  1.924712  1.061972
# 3 -1.856610 -3.338949 -1.617347 -2.484247 -0.656508  1.875134 -0.811140
# 4 -1.736858  0.399223  1.188889  1.965663  2.952093  0.020368 -1.089313
#
#          7         8         9   ...        20        21        22        23  \
# 0  4.502939  2.575816  0.729859  ... -0.014629  0.203726 -0.075084 -0.017159
# 1 -0.057963 -0.163093  0.272936  ... -0.075661 -0.235746  0.022060 -0.017280
# 2  0.780640 -0.601626  0.117667  ... -0.029157  0.073807  0.078994 -0.133004
# 3 -0.471649  0.090260  0.057053  ... -0.088731  0.002901  0.006623 -0.027417
# 4 -1.113194  1.100672  0.287144  ...  0.057553  0.002060 -0.256653 -0.126385
#
#          24        25        26        27        28        29
# ...

# %%
pca_loading = pd.DataFrame(pca.components_ * np.sqrt(pca.explained_variance_))

# %%
pca_loading
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.209321  1.072731 -0.180014 -0.104540 -0.330727  0.051009  0.386294
# 1   0.316974 -0.093395  0.191861  0.674673 -0.070509  0.012926  0.171136
# 2  -0.021450 -0.344996  0.051532 -0.210341  0.055552 -0.076682 -0.248767
# 3  -0.286108  0.495674  0.140157 -0.347565  0.568270 -0.000183 -0.101926
# 4  -0.156645 -0.093584  0.935526 -0.058282  0.595193 -0.263432  0.391176
# 5  -0.152842  0.382712  0.182121 -0.109088 -0.267202 -0.249493  0.149976
# 6  -0.182927 -0.490814  0.123889 -0.072435 -0.353660  0.469760  0.236355
# 7   0.931503  0.022211 -0.287061  0.388102 -0.043711 -0.458882  0.241789
# 8   0.883151 -0.251171 -0.018783  0.118567  0.391790  0.672494 -0.082517
# 9   0.397971 -0.189576  0.414183 -0.033189 -0.147922 -0.210378 -0.003591
# 10 -0.552706  0.159851 -0.419601  0.019476  0.149026  0.018668  0.578177
# 11  0.512724  0.302276 -0.211957  0.061805  0.060411 -0.151196  0.056009
# ...
